# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# US county file

us_county_file = "../us_county.csv"
us_county_df = pd.read_csv(us_county_file)
us_county_df.head(15)
# Out:
#     fips           county    state state_code    male  female  median_age  \
# 0   1001   Autauga County  Alabama         AL   26874   28326        37.8
# 1   1003   Baldwin County  Alabama         AL  101188  106919        42.8
# 2   1005   Barbour County  Alabama         AL   13697   12085        39.9
# 3   1007      Bibb County  Alabama         AL   12152   10375        39.9
# 4   1009    Blount County  Alabama         AL   28434   29211        40.8
# 5   1011   Bullock County  Alabama         AL    5663    4689        39.6
# 6   1013    Butler County  Alabama         AL    9368   10657        40.7
# 7   1015   Calhoun County  Alabama         AL   55315   59783        39.7
# 8   1017  Chambers County  Alabama         AL   16257   17569        43.0
# 9   1019  Cherokee County  Alabama         AL   12820   13033        45.9
# 10  1021   Chilton County  Alabama         AL   21672   22258        38.6
# 11  1023   Choctaw County  Alabama         AL    6253    6822        46.1
# ...

# %%
# US county covid file

covid_us_county_file = "../covid_us_county.csv"
covid_us_county_df = pd.read_csv(covid_us_county_file)
covid_us_county_df.head(15)
# Out:
#       fips   county    state        lat       long        date  cases  \
# 0   1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-22      0
# 1   1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-23      0
# 2   1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-24      0
# 3   1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-25      0
# 4   1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-26      0
# 5   1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-27      0
# 6   1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-28      0
# 7   1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-29      0
# 8   1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-30      0
# 9   1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-31      0
# 10  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-02-01      0
# 11  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-02-02      0
# ...

# %%
# PPP loan file

ppp_loan_ca_file = "../PPP_loan_CA.csv"
ppp_loan_ca_df = pd.read_csv(ppp_loan_ca_file)
ppp_loan_ca_df.head(15)
# Out:
#                                          BusinessName  \
# 0                              220 LABORATORIES, INC.
# 1                                A-C ELECTRIC COMPANY
# 2                                      A.O. REED & CO
# 3                           AARON THOMAS COMPANY, INC
# 4                            ACCURATE BACKGROUND, LLC
# 5   ADVANCED CHEMICAL TRANSPORT, INC., A CALIFORNI...
# 6             ADVANCED FRESH CONCEPTS FRANCHISE CORP.
# 7                              ADVANCED SYSTEMS GROUP
# 8                              ADVANTAGE MAILING INC.
# 9                             AGREEYA SOLUTIONS, INC.
# 10                      AIR SYSTEMS OF SACRAMENTO INC
# 11                  AIRPORT TERMINAL MANAGEMENT, INC.
# 12                              AKASH MANAGEMENT, LLC
# 13                                 ALATUS AEROSYSTEMS
# 14                                          ALIA CORP
#
#                          Address              City State    Zip  NAICSCode  \
# ...
